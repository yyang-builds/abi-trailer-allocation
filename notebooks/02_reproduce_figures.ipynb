# %% [markdown]
# # Reproduce Public Demo Figures
#
# This notebook runs the public-safe experiment pipeline and regenerates the main demo plots.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.append(str(PROJECT_ROOT / 'src'))

from abi_trailer.evaluation import run_public_experiment

artifacts = run_public_experiment(PROJECT_ROOT, PROJECT_ROOT / 'configs' / 'experiment_public.yaml')
artifacts['summary']
