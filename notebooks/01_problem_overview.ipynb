# %% [markdown]
# # Problem Overview
#
# This notebook gives a lightweight public walkthrough of the ABI-style trailer allocation problem.
#
# It is intentionally based on the synthetic demo dataset bundled with the repository, not on proprietary shipment records.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.append(str(PROJECT_ROOT / 'src'))

from abi_trailer.data_loader import load_demo_dataset

df = load_demo_dataset(PROJECT_ROOT)
df.head()
